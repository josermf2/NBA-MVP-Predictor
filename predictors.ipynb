# %%
import pandas as pd

# %%
mvps = pd.read_csv("data/mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1   Michael Jordan   27  CHI   77.0    891.0      960
# 1             1    2    Magic Johnson   31  LAL   10.0    497.0      960
# 2             2    3   David Robinson   25  SAS    6.0    476.0      960
# 3             3    4  Charles Barkley   27  PHI    2.0    222.0      960
# 4             4    5      Karl Malone   27  UTA    0.0    142.0      960
# ..          ...  ...              ...  ...  ...    ...      ...      ...
# 494           8    9    Stephen Curry   34  GSW    0.0      5.0     1000
# 495           9   10     Jimmy Butler   33  MIA    0.0      3.0     1000
# 496          10   11     De'Aaron Fox   25  SAC    0.0      2.0     1000
# 497          11  12T    Jalen Brunson   26  NYK    0.0      1.0     1000
# 498          12  12T        Ja Morant   23  MEM    0.0      1.0     1000
#
#      Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  \
# ...

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps.head()
# Out:
#             Player  Year  Pts Won  Pts Max  Share
# 0   Michael Jordan  1991    891.0      960  0.928
# 1    Magic Johnson  1991    497.0      960  0.518
# 2   David Robinson  1991    476.0      960  0.496
# 3  Charles Barkley  1991    222.0      960  0.231
# 4      Karl Malone  1991    142.0      960  0.148

# %%
players = pd.read_csv("data/players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 19584         699  535      Thaddeus Young  PF  34  TOR  54   9  14.7  2.0
# 19585         700  536          Trae Young  PG  24  ATL  73  73  34.8  8.2
# 19586         701  537      Omer Yurtseven   C  24  MIA   9   0   9.2  1.8
# 19587         702  538         Cody Zeller   C  30  MIA  15   2  14.5  2.5
# 19588         703  539         Ivica Zubac   C  25  LAC  76  76  28.6  4.3
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
del players["Unnamed: 0"]

# %%
del players["Rk"]

# %%
players["Player"] = players["Player"].str.replace("*","", regex=False)

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...  0.5
# 2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...  2.1
# 3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...  0.9
# 4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  TOT  68   2  13.6  1.7   4.0   .430  ...  1.4
# 9     Greg Anderson  PF  26  MIL  26   0   9.5  1.0   2.8   .370  ...  1.0
# 10    Greg Anderson  PF  26  NJN   1   0  18.0  4.0   4.0  1.000  ...  4.0
# 11    Greg Anderson  PF  26  DEN  41   2  16.1  2.1   4.7   .440  ...  1.6
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4   .456  ...  4.1
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8   .543  ...  2.4
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0   .548  ...  1.2
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0   .511  ...  0.6
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2   .496  ...  1.9
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6   .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# ...

# %%
def single_team(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"]=="TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

players = players.groupby(["Player", "Year"]).apply(single_team)
# Out:
# /tmp/ipykernel_1477284/2621837014.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   players = players.groupby(["Player", "Year"]).apply(single_team)

# %%
players
# Out:
#                                   Player Pos Age   Tm   G  GS    MP   FG  \
# Player         Year
# A.C. Green     1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1
#                1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7
#                1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6
#                1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7
#                1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8
# ...                                  ...  ..  ..  ...  ..  ..   ...  ...
# Željko Rebrača 2002 6095  Željko Rebrača   C  29  DET  74   4  15.9  2.6
#                2003 6595  Željko Rebrača   C  30  DET  30  12  16.3  2.7
#                2004 7176  Željko Rebrača   C  31  ATL  24   2  11.4  1.4
#                2005 7776  Željko Rebrača   C  32  LAC  58   2  16.0  2.3
#                2006 8370  Željko Rebrača   C  33  LAC  29   2  14.2  1.8
#
# ...

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players.head()
# Out:
#           Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  DRB  \
# 164   A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5  3.8
# 633   A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7  5.6
# 1092  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5  5.2
# 1579  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4  5.8
# 2067  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4  5.8
#
#       TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 164   6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 633   9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1092  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 1579  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 2067  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
#
# [5 rows x 30 columns]

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 467   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1412  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1911  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2381  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2948  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# ...

# %%
combined = players.merge(mvps, how="outer", on=["Player", "Year"])

# %%
combined[combined["Pts Won"] > 0]
# Out:
#               Player    Pos Age_x Tm_x G_x  GS  MP_x    FG   FGA FG%_x  ...  \
# 206     Al Jefferson      C    29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 360    Allen Iverson     PG    21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 362    Allen Iverson     SG    23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 363    Allen Iverson     SG    24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 364    Allen Iverson     SG    25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...   ...  ...  ..  ..   ...   ...   ...   ...  ...
# 14689   Vince Carter     SF    23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 14690   Vince Carter     SF    24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 14694   Vince Carter  SF-SG    28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 15082       Yao Ming      C    23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 15087       Yao Ming      C    28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
# ...

# %%
combined
# Out:
#                Player Pos Age_x Tm_x G_x  GS  MP_x   FG   FGA FG%_x  ...  \
# 0          A.C. Green  PF    27  LAL  82  21  26.4  3.1   6.6  .476  ...
# 1          A.C. Green  PF    28  LAL  82  53  35.4  4.7   9.8  .476  ...
# 2          A.C. Green  PF    29  LAL  82  55  34.4  4.6   8.6  .537  ...
# 3          A.C. Green  PF    30  PHO  82  55  34.5  5.7  11.3  .502  ...
# 4          A.C. Green  SF    31  PHO  82  52  32.8  3.8   7.5  .504  ...
# ...               ...  ..   ...  ...  ..  ..   ...  ...   ...   ...  ...
# 15231  Željko Rebrača   C    29  DET  74   4  15.9  2.6   5.1  .505  ...
# 15232  Željko Rebrača   C    30  DET  30  12  16.3  2.7   4.8  .552  ...
# 15233  Željko Rebrača   C    31  ATL  24   2  11.4  1.4   3.2  .442  ...
# 15234  Željko Rebrača   C    32  LAC  58   2  16.0  2.3   4.0  .568  ...
# 15235  Željko Rebrača   C    33  LAC  29   2  14.2  1.8   3.3  .542  ...
#
#       PTS_y TRB_y AST_y STL_y BLK_y FG%_y 3P%_y FT%_y  WS WS/48
# ...

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined
# Out:
#                Player Pos Age_x Tm_x G_x  GS  MP_x   FG   FGA FG%_x  ...  \
# 0          A.C. Green  PF    27  LAL  82  21  26.4  3.1   6.6  .476  ...
# 1          A.C. Green  PF    28  LAL  82  53  35.4  4.7   9.8  .476  ...
# 2          A.C. Green  PF    29  LAL  82  55  34.4  4.6   8.6  .537  ...
# 3          A.C. Green  PF    30  PHO  82  55  34.5  5.7  11.3  .502  ...
# 4          A.C. Green  SF    31  PHO  82  52  32.8  3.8   7.5  .504  ...
# ...               ...  ..   ...  ...  ..  ..   ...  ...   ...   ...  ...
# 15231  Željko Rebrača   C    29  DET  74   4  15.9  2.6   5.1  .505  ...
# 15232  Željko Rebrača   C    30  DET  30  12  16.3  2.7   4.8  .552  ...
# 15233  Željko Rebrača   C    31  ATL  24   2  11.4  1.4   3.2  .442  ...
# 15234  Željko Rebrača   C    32  LAC  58   2  16.0  2.3   4.0  .568  ...
# 15235  Željko Rebrača   C    33  LAC  29   2  14.2  1.8   3.3  .542  ...
#
#       PTS_y TRB_y AST_y STL_y BLK_y FG%_y 3P%_y FT%_y  WS WS/48
# ...

# %%
teams = pd.read_csv("data/teams.csv")

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  56  26  .683     —  111.5  105.7   5.22  1991
# 1              1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2              2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3              3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4              4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1098          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1099          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1100          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1101          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1102          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                       Team
# 0          Boston Celtics*
# 1      Philadelphia 76ers*
# 2         New York Knicks*
# 3       Washington Bullets
# 4          New Jersey Nets
# ...                    ...
# ...

# %%
teams = teams[~teams["W"].str.contains("Division")].copy()

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
sorted(teams["Team"].unique())
# Out:
# ['Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Charlotte Bobcats',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'New Jersey Nets',
#  'New Orleans Hornets',
#  'New Orleans Pelicans',
#  'New Orleans/Oklahoma City Hornets',
#  'New York Knicks',
#  'Oklahoma City Thunder',
#  'Orlando Magic',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Seattle SuperSonics',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Vancouver Grizzlies',
#  'Washington Bullets',
#  'Washington Wizards']

# %%
sorted(combined["Tm_x"].unique())
# Out:
# ['ATL',
#  'BOS',
#  'BRK',
#  'CHA',
#  'CHH',
#  'CHI',
#  'CHO',
#  'CLE',
#  'DAL',
#  'DEN',
#  'DET',
#  'GSW',
#  'HOU',
#  'IND',
#  'LAC',
#  'LAL',
#  'MEM',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NJN',
#  'NOH',
#  'NOK',
#  'NOP',
#  'NYK',
#  'OKC',
#  'ORL',
#  'PHI',
#  'PHO',
#  'POR',
#  'SAC',
#  'SAS',
#  'SEA',
#  'TOR',
#  'UTA',
#  'VAN',
#  'WAS',
#  'WSB']

# %%
nicknames = {}
with open("data/nicknames.txt") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev,name = line.replace("\n","").split(",")
        nicknames[abbrev] = name

# %%
combined["Team"] = combined["Tm_x"].map(nicknames)

# %%
combined.head()
# Out:
#        Player Pos Age_x Tm_x G_x  GS  MP_x   FG   FGA FG%_x  ... TRB_y AST_y  \
# 0  A.C. Green  PF    27  LAL  82  21  26.4  3.1   6.6  .476  ...   NaN   NaN
# 1  A.C. Green  PF    28  LAL  82  53  35.4  4.7   9.8  .476  ...   NaN   NaN
# 2  A.C. Green  PF    29  LAL  82  55  34.4  4.6   8.6  .537  ...   NaN   NaN
# 3  A.C. Green  PF    30  PHO  82  55  34.5  5.7  11.3  .502  ...   NaN   NaN
# 4  A.C. Green  SF    31  PHO  82  52  32.8  3.8   7.5  .504  ...   NaN   NaN
#
#   STL_y BLK_y FG%_y 3P%_y FT%_y  WS WS/48                Team
# 0   NaN   NaN   NaN   NaN   NaN NaN   NaN  Los Angeles Lakers
# 1   NaN   NaN   NaN   NaN   NaN NaN   NaN  Los Angeles Lakers
# 2   NaN   NaN   NaN   NaN   NaN NaN   NaN  Los Angeles Lakers
# 3   NaN   NaN   NaN   NaN   NaN NaN   NaN        Phoenix Suns
# 4   NaN   NaN   NaN   NaN   NaN NaN   NaN        Phoenix Suns
#
# [5 rows x 51 columns]

# %%
train = combined.merge(teams, how="outer",on=["Team", "Year"])

# %%
train
# Out:
#                   Player Pos Age_x Tm_x G_x  GS  MP_x   FG   FGA FG%_x  ...  \
# 0             Doc Rivers  PG    29  ATL  79  79  32.7  5.6  12.9  .435  ...
# 1      Dominique Wilkins  SF    31  ATL  81  81  38.0  9.5  20.2  .470  ...
# 2          Duane Ferrell  SF    25  ATL  78   2  14.9  2.2   4.6  .489  ...
# 3           Gary Leonard   C    23  ATL   4   0   2.3  0.0   0.0   NaN  ...
# 4            John Battle  SG    28  ATL  79   2  23.6  5.0  10.9  .461  ...
# ...                  ...  ..   ...  ...  ..  ..   ...  ...   ...   ...  ...
# 15231       Monte Morris  PG    27  WAS  62  61  27.3  4.0   8.3  .480  ...
# 15232    Quenton Jackson  PG    24  WAS   9   0  15.0  2.1   4.7  .452  ...
# 15233         Taj Gibson   C    37  WAS  49   2   9.8  1.3   2.6  .520  ...
# 15234   Vernon Carey Jr.   C    21  WAS  11   0   2.5  0.2   0.7  .250  ...
# 15235       Xavier Cooks  PF    27  WAS  10   1  12.6  1.7   2.8  .607  ...
#
# ...

# %%
del train["Unnamed: 0_y"]

# %%
train.dtypes
# Out:
# Player           object
# Pos              object
# Age_x            object
# Tm_x             object
# G_x              object
# GS               object
# MP_x             object
# FG               object
# FGA              object
# FG%_x            object
# 3P               object
# 3PA              object
# 3P%_x            object
# 2P               object
# 2PA              object
# 2P%              object
# eFG%             object
# FT               object
# FTA              object
# FT%_x            object
# ORB              object
# DRB              object
# TRB_x            object
# AST_x            object
# STL_x            object
# BLK_x            object
# TOV              object
# PF               object
# PTS_x            object
# Year              int64
# Unnamed: 0_x    float64
# Rank             object
# Age_y           float64
# Tm_y             object
# First           float64
# Pts Won         float64
# Pts Max         float64
# Share           float64
# ...

# %%
train = train.apply(pd.to_numeric, errors='ignore')
# Out:
# /tmp/ipykernel_1477284/3132000567.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   train = train.apply(pd.to_numeric, errors='ignore')

# %%
train.dtypes
# Out:
# Player           object
# Pos              object
# Age_x             int64
# Tm_x             object
# G_x               int64
# GS                int64
# MP_x            float64
# FG              float64
# FGA             float64
# FG%_x           float64
# 3P              float64
# 3PA             float64
# 3P%_x           float64
# 2P              float64
# 2PA             float64
# 2P%             float64
# eFG%            float64
# FT              float64
# FTA             float64
# FT%_x           float64
# ORB             float64
# DRB             float64
# TRB_x           float64
# AST_x           float64
# STL_x           float64
# BLK_x           float64
# TOV             float64
# PF              float64
# PTS_x           float64
# Year              int64
# Unnamed: 0_x    float64
# Rank             object
# Age_y           float64
# Tm_y             object
# First           float64
# Pts Won         float64
# Pts Max         float64
# Share           float64
# ...

# %%
train["GB"].unique()
# Out:
# array(['18.0', '29.0', '14.0', '—', '10.0', '26.0', '13.0', '12.0', '2.0',
#        '28.0', '27.0', '17.0', '15.0', '33.0', '46.0', '6.0', '22.0',
#        '16.0', '20.0', '21.0', '3.0', '25.0', '19.0', '5.0', '11.0',
#        '23.0', '12.5', '9.0', '8.0', '4.0', '35.0', '31.0', '1.0', '7.0',
#        '41.0', '24.0', '39.0', '45.0', '36.0', '37.0', '38.0', '4.5',
#        '30.0', '43.0', '25.5', '44.0', '40.0', '42.0', '2.5', '51.0',
#        '34.0', '32.0', '20.5', '32.5', '48.0', '52.0', '3.5', '56.0',
#        '10.5', '47.0', '11.5', '22.5', '1.5', '50.0', '21.5', '18.5'],
#       dtype=object)

# %%
train["GB"] = pd.to_numeric(train["GB"].str.replace("—","0"))

# %%
train.dtypes
# Out:
# Player           object
# Pos              object
# Age_x             int64
# Tm_x             object
# G_x               int64
# GS                int64
# MP_x            float64
# FG              float64
# FGA             float64
# FG%_x           float64
# 3P              float64
# 3PA             float64
# 3P%_x           float64
# 2P              float64
# 2PA             float64
# 2P%             float64
# eFG%            float64
# FT              float64
# FTA             float64
# FT%_x           float64
# ORB             float64
# DRB             float64
# TRB_x           float64
# AST_x           float64
# STL_x           float64
# BLK_x           float64
# TOV             float64
# PF              float64
# PTS_x           float64
# Year              int64
# Unnamed: 0_x    float64
# Rank             object
# Age_y           float64
# Tm_y             object
# First           float64
# Pts Won         float64
# Pts Max         float64
# Share           float64
# ...

# %%
train.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = train[train["G_x"] > 70].sort_values("PTS_x", ascending=False).head(10)

# %%
import matplotlib
highest_scoring.plot.bar("Player", "PTS_x")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_scoring_by_year = train.groupby("Year").apply(lambda x: x.sort_values("PTS_x", ascending=False).head(1))
# Out:
# /tmp/ipykernel_1477284/4020768105.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   highest_scoring_by_year = train.groupby("Year").apply(lambda x: x.sort_values("PTS_x", ascending=False).head(1))

# %%
highest_scoring_by_year.plot.bar("Year", "PTS_x")
# Out:
# <Axes: xlabel='Year'>

# %%
train.groupby("Year").apply(lambda x: x.shape[0])
# Out:
# /tmp/ipykernel_1477284/3126292839.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   train.groupby("Year").apply(lambda x: x.shape[0])
# Year
# 1991    385
# 1992    386
# 1993    390
# 1994    403
# 1995    405
# 1996    428
# 1997    441
# 1998    439
# 1999    440
# 2000    439
# 2001    441
# 2002    440
# 2003    428
# 2004    442
# 2005    464
# 2006    458
# 2007    458
# 2008    450
# 2009    443
# 2010    442
# 2011    452
# 2012    478
# 2013    467
# 2014    480
# 2015    492
# 2016    476
# 2017    486
# 2018    540
# 2019    530
# 2020    529
# 2021    540
# 2022    605
# 2023    539
# dtype: int64

# %%
train.corr()["Share"]
# Out:
# Age        0.018596
# G          0.089282
# GS         0.167476
# MP         0.162175
# FG         0.276365
# FGA        0.249254
# FG%        0.065789
# 3P         0.096225
# 3PA        0.096460
# 3P%        0.013611
# 2P         0.275976
# 2PA        0.251885
# 2P%        0.063240
# eFG%       0.059335
# FT         0.316392
# FTA        0.321457
# FT%        0.037875
# ORB        0.101375
# DRB        0.213241
# TRB        0.186209
# AST        0.200253
# STL        0.175041
# BLK        0.154713
# TOV        0.233015
# PF         0.071046
# PTS        0.288267
# Year      -0.008135
# Pts Won    0.995153
# Pts Max    0.521335
# Share      1.000000
# W          0.122718
# L         -0.121866
# W/L%       0.126559
# GB        -0.101014
# PS/G       0.045206
# PA/G      -0.039617
# SRS        0.122782
# Name: Share, dtype: float64
